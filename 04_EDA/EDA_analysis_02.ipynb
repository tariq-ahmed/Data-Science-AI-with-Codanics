# %% [markdown]
# # Pakistani Population Analysis

# %% [markdown]
# **Author Name:** Tariq Ahmed \
# **Email:** engr.tariqahmed11@gmail.com

# %% [markdown]
# The Data was collected from the [link](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset)
#
# **Years of Data:**
#
# 1. 2017
# 2. 1998

# %% [markdown]
# ## **The Dataset collected from the source has following**

# %% [markdown]
# ``Description``
# Description This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# Features Province: The administrative provinces or regions of Pakistan where the census data was collected.
#
# Division: The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# ``District``: Districts within each division, representing larger administrative units.
#
# ``Sub-Division``: Sub-divisions or tehsils within each district, providing more localized data.
#
# ``Area``: The land area (in square kilometers) of each sub-division.
#
# ``Urban Population 2017``: The population of urban areas within each sub-division for the year 2017.
#
# ``Rural Population 2017``: The population of rural areas within each sub-division for the year 2017.
#
# ``Male Population 2017``: The male population within each sub-division for the year 2017.
#
# ``Female Population 2017``: The female population within each sub-division for the year 2017.
#
# ``Transgender Population 2017``: The population of transgender individuals within each sub-division for the year 2017.
#
# ``Sex Ratio 2017:`` The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# ``Population in 1998``: The total population of each sub-division as recorded in the 1998 census.
#
# ``Annual Growth Rate:`` The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# Data Source The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# Data Usage Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## Purpose of Ananlysis:
#
# We will fill this at the end or during the process

# %%
#  Import the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the Dataset
df = pd.read_csv(r'C:\Users\Tariq\Desktop\vscode_environmnets\pandas_tips_tricks\data\population_pakistan.csv')

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %% [markdown]
# # 1. Composition

# %%
#  Explore the data (Composition)

df.info() # check the columns, rows, index, numerical, categorical etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
df.head()   # check the first 5 rows
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
#  max columns printing option
pd.set_option('display.max_columns', None) # None means all columns will be printed in output window

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
#  lets see the all columns at once
df.columns # it will return the list of all columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# lets look on the data types
df.dtypes # it will return the data types of all columns
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
# summary statistics
df.describe() # it will return the summary statistics of all columns
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
#  check the null or missing values in the dataset
df.isnull().sum() # it will return the sum of null values in each column
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
# histplot
sns.histplot(df['AREA (sq.km)']) # histogram plot of AREA (sq.km) column
# Out:
# <Axes: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
sns.histplot(df, x = 'AREA (sq.km)') # histogram plot of AREA (sq.km) column
# Out:
# <Axes: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
#  Box plot
sns.boxplot(df, y= 'AREA (sq.km)') # box plot of AREA (sq.km) column
# Out:
# <Axes: ylabel='AREA (sq.km)'>

# %%
#  summary statistics transposed
df.describe().T # it will return the summary statistics of all columns in transposed form
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
sns.boxplot(df, x = 'PROVINCE', y = 'ALL SEXES (RURAL)')
# Out:
# <Axes: xlabel='PROVINCE', ylabel='ALL SEXES (RURAL)'>

# %%
sns.boxenplot(df, x = 'DIVISION', y = 'ALL SEXES (RURAL)') # boxen plot of ALL SEXES (RURAL) column
# Out:
# <Axes: xlabel='DIVISION', ylabel='ALL SEXES (RURAL)'>

# %%
#  it is very hard to plot, therefore, we will use groupby function to make tabulated data output.

df.DISTRICT.unique() # it will return the unique values of DISTRICT column
# Out:
# array(['BAHAWALNAGAR DISTRICT', 'BAHAWALPUR DISTRICT',
#        'RAHIM YAR KHAN DISTRICT', 'DERA GHAZI KHAN DISTRICT',
#        'LAYYAH DISTRICT', 'MUZAFFARGARH DISTRICT', 'RAJANPUR DISTRICT',
#        'CHINIOT DISTRICT', 'FAISALABAD DISTRICT', 'JHANG DISTRICT',
#        'TOBA TEK SINGH DISTRICT', 'GUJRANWALA DISTRICT',
#        'GUJRAT DISTRICT', 'HAFIZABAD DISTRICT',
#        'MANDI BAHAUDDIN DISTRICT', 'NAROWAL DISTRICT', 'SIALKOT DISTRICT',
#        'KASUR DISTRICT', 'LAHORE DISTRICT', 'NANKANA SAHIB DISTRICT',
#        'SHEIKHUPURA DISTRICT', 'KHANEWAL DISTRICT', 'LODHRAN DISTRICT',
#        'MULTAN DISTRICT', 'VEHARI DISTRICT', 'ATTOCK DISTRICT',
#        'CHAKWAL DISTRICT', 'JHELUM DISTRICT', 'RAWALPINDI DISTRICT',
#        'OKARA DISTRICT', 'PAKPATTAN DISTRICT', 'SAHIWAL DISTRICT',
#        'BHAKKAR DISTRICT', 'KHUSHAB DISTRICT', 'MIANWALI DISTRICT',
#        'SARGODHA DISTRICT', 'BADIN DISTRICT', 'DADU DISTRICT',
# ...

# %%
df.DISTRICT.nunique() # it will return the number of unique values of DISTRICT column
# Out:
# 131

# %%
df.DIVISION.nunique() # it will return the number of unique values of DIVISION column
# Out:
# 28

# %%
len(df) # it will return the number of rows in the dataset
# Out:
# 528

# %%
df.groupby(['DIVISION']).size() # it will return the number of rows in the dataset grouped by DIVISION column
# Out:
# DIVISION
# BAHAWALPUR DIVISION             15
# BANNU DIVISION                  15
# Badin Division                   5
# D.G.KHAN DIVISION               14
# DERA ISMAIL KHAN DIVISION       15
# FAISALABAD DIVISION             17
# GUJRANWALA DIVISION             20
# HAZARA DIVISION                 15
# Hyderabad Division              30
# KOHAT DIVISION                  14
# Kalat Division                  18
# Karachi Division                30
# LAHORE DIVISION                 17
# Larkana Division                21
# MALAKAND DIVISION               33
# MARDAN DIVISION                  7
# MULTAN DIVISION                 14
# Makran Division                 37
# Mirpurkhas Division             18
# Naseerabad Division             19
# PESHAWAR DIVISION               18
# Quetta Division                 38
# RAWALPINDI DIVISION             22
# SAHIWAL DIVISION                 7
# SARGODHA DIVISION               17
# Shaheed Benazirabad Division    15
# ...

# %%
df.groupby(['DIVISION']).size().sort_values() # it will return the number of rows in the dataset grouped by DIVISION column in ascending order
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# HAZARA DIVISION                 15
# BAHAWALPUR DIVISION             15
# DERA ISMAIL KHAN DIVISION       15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# LAHORE DIVISION                 17
# Kalat Division                  18
# Sukkur Division                 18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Naseerabad Division             19
# Zhob Division                   19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Karachi Division                30
# Hyderabad Division              30
# MALAKAND DIVISION               33
# ...

# %%
df.groupby('DIVISION')['ALL SEXES (RURAL)'].mean() # it will return the mean of ALL SEXES (RURAL) column grouped by DIVISION column
# Out:
# DIVISION
# BAHAWALPUR DIVISION             575317.533333
# BANNU DIVISION                  167286.866667
# Badin Division                  282922.800000
# D.G.KHAN DIVISION               614505.142857
# DERA ISMAIL KHAN DIVISION       156810.200000
# FAISALABAD DIVISION             526807.764706
# GUJRANWALA DIVISION             510698.200000
# HAZARA DIVISION                 316744.800000
# Hyderabad Division              176117.800000
# KOHAT DIVISION                  179610.571429
# Kalat Division                   60748.777778
# Karachi Division                 38016.400000
# LAHORE DIVISION                 348967.882353
# Larkana Division                201900.333333
# MALAKAND DIVISION               253212.515152
# MARDAN DIVISION                 468955.714286
# MULTAN DIVISION                 632220.785714
# Makran Division                  42605.432432
# Mirpurkhas Division             189710.722222
# Naseerabad Division              70283.578947
# ...

# %%
df.groupby('DISTRICT')['ALL SEXES (RURAL)'].mean() # it will return the mean of ALL SEXES (RURAL) column grouped by DISTRICT column
# Out:
# DISTRICT
# ABBOTTABAD DISTRICT      378963.250000
# ATTOCK DISTRICT          232578.333333
# AWARAN DISTRICT           21896.000000
# BADIN DISTRICT           282922.800000
# BAHAWALNAGAR DISTRICT    471194.000000
#                              ...
# UPPER DIR DISTRICT       367256.833333
# VEHARI DISTRICT          798650.666667
# WASHUK DISTRICT           30775.400000
# ZHOB DISTRICT             52838.000000
# ZIARAT DISTRICT           78351.500000
# Name: ALL SEXES (RURAL), Length: 131, dtype: float64

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
pd.set_option('display.max_rows', None) # None means all rows will be printed in output window

# %%
df.groupby(['PROVINCE','DIVISION','DISTRICT','SUB DIVISION'])['ALL SEXES (RURAL)'].mean() # it will return the mean of ALL SEXES (RURAL) column grouped by PROVINCE, DIVISION, DISTRICT, SUB-DIVISION columns
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   5721.0
#                                                                          JOHAN SUB-TEHSIL                 10708.0
#                                                                          KALAT TEHSIL                     92298.0
#                                                                          MANGOCHAR TEHSIL                 65678.0
#                                                                          SURAB TEHSIL                    165260.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                42318.0
#                                                                          KARAKH SUB-TEHSIL                31016.0
# ...

# %%
df.groupby(['PROVINCE','DIVISION','DISTRICT','SUB DIVISION'])['POPULATION 1998 (RURAL)'].mean() # it will return the mean of POPULATION 1998 (RURAL) column grouped by PROVINCE, DIVISION, DISTRICT, SUB-DIVISION columns
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   3979.0
#                                                                          JOHAN SUB-TEHSIL                 12299.0
#                                                                          KALAT TEHSIL                     63919.0
#                                                                          MANGOCHAR TEHSIL                 41590.0
#                                                                          SURAB TEHSIL                     82253.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                28561.0
#                                                                          KARAKH SUB-TEHSIL                21984.0
# ...

# %%
df.groupby(['PROVINCE','DIVISION','DISTRICT','SUB DIVISION'])['POPULATION 1998 (RURAL)'].min() # it will return the min of POPULATION 1998 (RURAL) column grouped by PROVINCE, DIVISION, DISTRICT, SUB-DIVISION columns
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   3979
#                                                                          JOHAN SUB-TEHSIL                 12299
#                                                                          KALAT TEHSIL                     63919
#                                                                          MANGOCHAR TEHSIL                 41590
#                                                                          SURAB TEHSIL                     82253
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                28561
#                                                                          KARAKH SUB-TEHSIL                21984
#                                                                          KHUZDAR TEHSIL                   70788
# ...

# %%
df.groupby ('PROVINCE')['POPULATION 1998 (RURAL)'].mean() # it will return the mean of POPULATION 1998 (RURAL) column grouped by PROVINCE column
# Out:
# PROVINCE
# BALOCHISTAN     37944.450382
# KPK            209638.816901
# KPK/FATA        62657.086957
# PUNJAB         350172.034965
# SINDH          113796.167883
# Name: POPULATION 1998 (RURAL), dtype: float64

# %%
df.groupby(['PROVINCE', 'DIVISION'])['POPULATION 1998 (RURAL)'].mean() # it will return the mean of POPULATION 1998 (RURAL) column grouped by PROVINCE, DIVISION columns
# Out:
# PROVINCE     DIVISION
# BALOCHISTAN  Kalat Division                   34953.666667
#              Makran Division                  30517.081081
#              Naseerabad Division              45926.000000
#              Quetta Division                  39651.921053
#              Zhob Division                    43845.157895
# KPK          BANNU DIVISION                  267784.500000
#              DERA ISMAIL KHAN DIVISION       154943.833333
#              HAZARA DIVISION                 213571.066667
#              KOHAT DIVISION                  151992.285714
#              MALAKAND DIVISION               167573.346154
#              MARDAN DIVISION                 287508.857143
#              PESHAWAR DIVISION               374429.000000
# KPK/FATA     BANNU DIVISION                   34714.636364
#              DERA ISMAIL KHAN DIVISION        52092.333333
#              KOHAT DIVISION                   79378.000000
#              MALAKAND DIVISION                85032.428571
# ...

# %%
df.describe().T # 2017 and 1998
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %% [markdown]
# ## Rural population in 2017

# %%
df['ALL SEXES (RURAL)'].sum() # it will return the sum of ALL SEXES (RURAL) column
# Out:
# 130034790

# %%
print('The Total Rural Population of Pakistan in 2017 was:' , df['ALL SEXES (RURAL)'].sum()) # it will return the sum of ALL SEXES (RURAL) column
# Out:
# The Total Rural Population of Pakistan in 2017 was: 130034790

# %% [markdown]
# ## Rural Population in 1998

# %%
print('The Total Rural Population of Pakistan in 1998 was:' , df['POPULATION 1998 (RURAL)'].sum()) #  it will return the sum of POPULATION 1998 (RURAL) column
# Out:
# The Total Rural Population of Pakistan in 1998 was: 88401981

# %% [markdown]
# ## How much rural population increased from 1998 - 2017?

# %%
#  How much rural population increased from 1998 - 2017?
pop_rural_1998 = df['POPULATION 1998 (RURAL)'].sum()
pop_rural_2017 = df['ALL SEXES (RURAL)'].sum()

pop_change = pop_rural_2017 - pop_rural_1998

print('The Total Rural Population of Pakistan have been increased by 2017 as compared to 1998 is:' , pop_change)
# Out:
# The Total Rural Population of Pakistan have been increased by 2017 as compared to 1998 is: 41632809

# %% [markdown]
# ## Assignment: Calculate the percentage change of Population?

# %%
percent_change = ((pop_rural_2017 - pop_rural_1998) / pop_rural_1998) * 100 # it will return the percentage change of population from 1998 to 2017 
percent_change
# Out:
# 47.094882409931515

# %% [markdown]
# # OR

# %%
per_change = pop_change / pop_rural_1998 * 100 # it will return the percentage change of population from 1998 to 2017 
per_change
# Out:
# 47.094882409931515

# %% [markdown]
# ## Urban Population

# %%
#  How much Urban population increased from 1998 - 2017?
pop_urban_1998 = df['POPULATION 1998 (URBAN)'].sum()
pop_urban_2017 = df['ALL SEXES (URBAN)'].sum()

pop_change_urban = pop_urban_2017 - pop_urban_1998
pop_change_urban

print('The Total Urban Population of Pakistan have been increased by 2017 as compared to 1998 is:' , pop_change_urban)
# Out:
# The Total Urban Population of Pakistan have been increased by 2017 as compared to 1998 is: 32059612

# %% [markdown]
# ## **Assignment**: How to combine 3 columns in one column? make a separate data of everything based on Sex(Male,Female,Transgender). Sex_Urban, Sex_Rural columns

# %%
# ## **Assignment**: How to combine 3 columns in one column? make a separate data of everything based on Sex(Male,Female,Transgender). Sex_Urban, Sex_Rural columns

df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# combine 3 columns in one column
df_sex_rural = df['MALE (RURAL)'] + df['FEMALE (RURAL)'] + df['TRANSGENDER (RURAL)'] # it will combine 3 columns in one column
df_sex_rural
# Out:
# 0       619550
# 1       540342
# 2       361240
# 3       382115
# 4       452723
# 5       902476
# 6            0
# 7       467938
# 8       340747
# 9       221431
# 10      564422
# 11      749218
# 12      982018
# 13     1045577
# 14      999966
# 15      212652
# 16      827602
# 17      705564
# 18      580592
# 19      204169
# 20      783612
# 21      595880
# 22      555795
# 23     1093354
# 24     1385109
# 25       34191
# 26      739299
# 27      494109
# 28      391144
# 29      339754
# 30      277268
# 31      329407
# 32      284170
# 33       34101
# 34     1425154
# 35     1267317
# 36      486176
# 37      618660
# 38      268160
# 39      365900
# 40     1035377
# 41      474764
# 42      482391
# 43      236336
# 44      378026
# 45      652771
# 46       73890
# 47      641189
# 48      330876
# 49      485434
# 50      530559
# 51      954998
# 52      781334
# 53      192457
# 54      400049
# 55      354176
# 56      328748
# 57      451306
# ...

# %%
# combine 3 columns in one column
df_sex_urban = df['MALE (URBAN)'] + df['FEMALE (URBAN)'] + df['TRANSGENDER (URBAN)'] # it will combine 3 columns in one column
df_sex_urban
# Out:
# 0       193840
# 1       149424
# 2        61528
# 3       142600
# 4        72294
# 5       176110
# 6       682116
# 7       107948
# 8       115613
# 9        41492
# 10       48883
# 11      232867
# 12       51888
# 13      484606
# 14      261622
# 15           0
# 16      397362
# 17       51666
# 18       97193
# 19       48371
# 20      193476
# 21       44504
# 22      159382
# 23      254147
# 24      240378
# 25           0
# 26      110090
# 27      212661
# 28       14545
# 29       34087
# 30      278528
# 31      109615
# 32       48796
# 33     3210158
# 34       39873
# 35      226606
# 36      156938
# 37       84495
# 38       27554
# 39       67634
# 40      429441
# 41       73803
# 42      174831
# 43      135674
# 44       44220
# 45       87246
# 46      185874
# 47     2165340
# 48      248814
# 49       49377
# 50      299713
# 51      542708
# 52      229928
# 53       54864
# 54      263867
# 55      138862
# 56       43423
# 57      217232
# ...
