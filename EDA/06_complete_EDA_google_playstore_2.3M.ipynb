# %% [markdown]
# # **Google playstore 2.3M Data**
# **Complete Exploratory Data Analysis**

# %% [markdown]
# ## About Dataset
#
# >- **`Description`**\
# > The Data Set was downloaded from Kaggle, from the following [link](https://www.kaggle.com/datasets/gauthamp10/google-playstore-apps/data)
#
#
# - `Context`
# Google PlayStore Android App Data. (2.3 Million+ App Data)
# Backup repo: https://github.com/gauthamp10/Google-Playstore-Dataset
#
# - `Content`
# I've collected the data with the help of Python script (Scrapy) running on a cloud vm instance.
# The data was collected in the month of June 2021.
#
# - `Also checkout`:
#
# - `Apple AppStore Apps dataset`: https://www.kaggle.com/gauthamp10/apple-appstore-apps
#
# - `Android App Permission dataset`: https://www.kaggle.com/gauthamp10/app-permissions-android
#
# - `Acknowledgements`
# I couldn't have build this dataset without the help of Github Education and switched to facundoolano/google-play-scraper for sane reasons.
#
# - `Inspiration`
# Took inspiration from: https://www.kaggle.com/lava18/google-play-store-apps to build a big database for students and researchers.
#
# Author
# `Gautham Prakash`
#
# My other projects: github.com/gauthamp10
#
# Website: gauthamp10.github.io

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#this is for jupyter notebook to show the plot in the notebook itself instead of opening a new window for the plot
# %matplotlib inline

# %% [markdown]
# ## 2. **Data Loading and exploration and cleaning**
#  ↪ Load the csv file with the pandas
#
#  ↪ creating the dataframe and understanding the data present in the dataset using pandas
#
#  ↪ Dealing with the missing data, outliers and the incorrect records

# %%
df = pd.read_csv(r'C:\Users\Tariq\Desktop\vscode_environmnets\Data-Science-AI-with-Codanics\data_sets\google-Playstore-2.3 Million.csv')

# %% [markdown]
# - Viewing the first five Rows of the data

# %%
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %% [markdown]
# > **Note**: Some the output of notebook does not present the complete output, therefore we can increase the limit of columns view and row view by using these commands:

# %%
pd.set_option('display.max_columns', None) # this is to display all the columns in the dataframe
pd.set_option('display.max_rows', None) # this is to display all the rows in the dataframe

# %%
# hide all warnings runtime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - let's see the exact column names which can be easily copied later on from Google Playstore Dataset

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %% [markdown]
# - Let's have a look on the shape of the dataset

# %%
df.shape
# Out:
# (2312944, 24)

# %% [markdown]
# - Not enough, let's have a look on the columns and their data types using detailed info function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %% [markdown]
# # **Observations**
# ---
# 1. There are 2312944 rows and 24 columns in the dataset
# 2. The columns are of different data types
# 3. The columns in the datasets are:
#    - `'App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'`
#
# 4. There are some columns which are of object data type but they should be of numeric data type, we will convert them later on in the notebook.
#    - `'Installs', 'Size'`

# %%
df.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %% [markdown]
# ## Observations:
# ---
# - We have only 5 columns as numeric data type, rest all are object data type (according to python), but we can see that `'Size', 'Installs'` are also numeric, we must convert them to numeric data type in data wrangling process.
# ---

# %% [markdown]
# - Let's clean the `Size` column first

# %%
# check for null values
df['Size'].isnull().sum()
# Out:
# 196

# %%
df['Size'].isnull().sum()/len(df)*100
# Out:
# 0.008474048658333275

# %% [markdown]
# "The 'size' column has a small amount of missing data (0.008%). To address this, we are filling in those gaps using the mean imputing method, ensuring we have complete data for our analysis."

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    74777
# 11M                   62157
# 12M                   56080
# 13M                   48034
# 14M                   45211
# 16M                   42474
# 15M                   41306
# 17M                   37244
# 10M                   34114
# 18M                   31707
# 19M                   29723
# 21M                   29023
# 20M                   28796
# 22M                   28261
# 23M                   27337
# 24M                   25301
# 25M                   25023
# 26M                   23897
# 27M                   21826
# 28M                   21157
# 29M                   20050
# 37M                   18658
# 30M                   18625
# 31M                   18150
# 4.9M                  17967
# 32M                   17629
# 4.2M                  17421
# 3.8M                  17193
# 3.7M                  16927
# 38M                   16811
# 3.4M                  16752
# 33M                   16681
# 4.0M                  16481
# ...

# %% [markdown]
# -  There are several uniques values in the `Size` column, we have to first make the unit into one common unit from M and K to bytes, and then remove the `M` and `K` from the values and convert them into numeric data type.

# %%
# find the values in size column which has 'M' in it
df['Size'].fillna('0', inplace=True)
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 2201705

# %%
# find the values in size column which has 'k' in it
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 36253

# %%
# find the values in size column which has 'Varies with device' in it
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# 74777

# %%
# taking sum of all the values in size column which has 'M', 'K' and 'varies with device' in it
2201705+36253+74777
# Out:
# 2312735

# %%
2312944-2312735
# Out:
# 209

# %%
# Total Values in Size column
df['Size'].value_counts().sum()
# Out:
# 2312944

# %%
# check the null values in size column
df['Size'].isnull().sum()
# Out:
# 0

# %%
# check the unique values in size column
df['Size'].unique()
# Out:
# array(['10M', '2.9M', '3.7M', ..., '405M', '3.2k', '512M'], dtype=object)

# %% [markdown]
# - We have `2201705` values in `M` units
# - We have `36253` values in `k` units
# - We have `74777` value in `Varies with device`
#
# > Let's convert the `M` and `K` units into bytes and then remove the `M` and `K` from the values and convert them into numeric data type.

# %%
def convert_size(size):
    if isinstance(size, str):
        size = size.replace(',', '')  # remove comma from size string
        if 'k' in size:
            return float(size.replace('k', '')) * 1024
        elif 'M' in size:
            return float(size.replace('M', '')) * 1024 * 1024
        elif 'Varies with device' in size:
            return np.nan
    return size

df['Size'] = df['Size'].apply(convert_size)

# %%
# rename the column name 'Size' to 'Size_in_bytes'
df.rename(columns={'Size': 'Size_in_bytes'}, inplace=True)

# %%
# Convert 'Size_in_bytes' column to numeric data type
df['Size_in_bytes'] = pd.to_numeric(df['Size_in_bytes'], errors='coerce')

# Making a new column called 'Size_in_Mb' which will have the size in MB
df['Size_in_Mb'] = df['Size_in_bytes'].apply(lambda x: x/(1024*1024))

# %% [markdown]
# - Now we have converted every value into bytes and removed the `M` and `K` from the values and converted them into numeric data type.
# - 'Varies with device' was a string value, therefore we intentionally converted them into null values, which we can fill later on according to our needs.
#
# ---
# - Let's have a look on the `Installs` column

# %%
# check the unique values in Installs column
df['Installs'].unique()
# Out:
# array(['10+', '5,000+', '50+', '100+', '1,000+', '500+', '50,000+',
#        '10,000+', '1+', '500,000+', '100,000+', '5+', '10,000,000+',
#        '1,000,000+', '5,000,000+', '0+', '100,000,000+', nan,
#        '50,000,000+', '1,000,000,000+', '500,000,000+', '5,000,000,000+',
#        '10,000,000,000+'], dtype=object)

# %%
# let's have a values counts
df['Installs'].value_counts()
# Out:
# Installs
# 100+               443368
# 1,000+             398199
# 10+                300156
# 10,000+            256723
# 500+               189077
# 50+                170465
# 5,000+             143593
# 100,000+           110257
# 50,000+             75359
# 5+                  73772
# 1+                  65345
# 1,000,000+          33650
# 500,000+            27012
# 0+                  11566
# 5,000,000+           6595
# 10,000,000+          6192
# 50,000,000+           824
# 100,000,000+          549
# 500,000,000+           65
# 1,000,000,000+         55
# 5,000,000,000+         14
# 10,000,000,000+         1
# Name: count, dtype: int64

# %%
df['Installs'].fillna('', inplace=True)
df['Installs'].loc[df['Installs'].str.contains('\+')].value_counts().sum() # find how many values has '+' in it
# Out:
# 2312837

# %%
# Total values in Installs column
df['Installs'].value_counts().sum()
# Out:
# 2312944

# %% [markdown]
# - The only problem I see here is the `+` sign in the values, let's remove them and convert the column into numeric data type.
#
# - The total values in the `Installs` column are `2312944` and there are no null values in the column.
#
# - Let's remove the plus sign `+` and `,` from the values and convert them into numeric data type

# %%
# remove the plus sign from install column and convert it to numeric
df['Installs'] = df['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
# also remove the commas from the install column
df['Installs'] = df['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
# convert the install column to numeric (integers because this is the number of installs/count)
df['Installs'] = df['Installs'].apply(lambda x: int(x) if x != '' else 0)

# %% [markdown]
# - Let's verify if the dtypes has been changes and the `+` and `,` sign has been removed

# %%
df.head() # check the head of the dataframe
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count  Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0        10
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0      5000
# 2        com.doantiepvien.crm   Productivity     0.0           0.0        50
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0        10
# 4        com.horodyski.grower          Tools     0.0           0.0       100
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size_in_bytes  \
# 0              10.0                15  True    0.0      USD     10485760.0
# ...

# %%
df['Installs'].dtype # this will show the data type of the column
# Out:
# dtype('int64')

# %% [markdown]
# - We can generate a new columns based on the installation values, which will be helpful in our analysis

# %%
df['Installs'].max() # this will show the maximum value in the column
# Out:
# 10000000000

# %%
# making a new column called 'Installs_category' which will have the category of the installs
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['no', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['Installs_category'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df['Installs_category'].value_counts() # check the value counts of the new column
# Out:
# Installs_category
# Low                   1201109
# Very low               439273
# Moderate               400316
# More than moderate     185616
# High                    60662
# Very High               12787
# no                      11673
# Top Notch                1508
# Name: count, dtype: int64

# %%
# using f string to print the min, max and average price of the apps
print(f"Min price is: {df['Price'].min()} $")
print(f"Max price is: {df['Price'].max()} $")
print(f"Average price is: {df['Price'].mean()} $")
# Out:
# Min price is: 0.0 $
# Max price is: 400.0 $
# Average price is: 0.10349915833370804 $

# %% [markdown]
# ### **2.1. Descriptive Statistics**

# %%
df.describe() # check the description of the dataframe
# Out:
#              Rating  Rating Count      Installs  Minimum Installs  \
# count  2.290061e+06  2.290061e+06  2.312944e+06      2.312837e+06
# mean   2.203152e+00  2.864839e+03  1.834367e+05      1.834452e+05
# std    2.106223e+00  2.121626e+05  1.513109e+07      1.513144e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00  5.000000e+01      5.000000e+01
# 50%    2.900000e+00  6.000000e+00  5.000000e+02      5.000000e+02
# 75%    4.300000e+00  4.200000e+01  5.000000e+03      5.000000e+03
# max    5.000000e+00  1.385576e+08  1.000000e+10      1.000000e+10
#
#        Maximum Installs         Price  Size_in_bytes    Size_in_Mb
# count      2.312944e+06  2.312944e+06   2.238154e+06  2.238154e+06
# mean       3.202017e+05  1.034992e-01   2.013260e+07  1.919994e+01
# std        2.355495e+07  2.633127e+00   2.504606e+07  2.388578e+01
# min        0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# ...

# %% [markdown]
# ## Observations:
# ---
# - Now, we have only 8 columns as numeric data type.
# - We can observe their descriptive statistics. and make tons of observations as per our hypotheses.
# - We can see that the `Rating` column has a minimum value of `0` and a maximum value of `5`, which is the range of rating, and the mean is `2.2` rating. On an average people give this rating.
#
# - Similarly, we can observe the other columns as well.
#
# Therefore, the most important thing is to classify as app based on the correlation matrix and then observe the descriptive statistics of the app category and number of installs, Size, ratings, etc.
#
# But even before that we have to think about the missing values in the dataset.
# ---

# %% [markdown]
# ## **2.2. Dealing with the missing values**
# Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.

# %% [markdown]
# - Let's have a look on the missing values in the dataset

# %%
df.isnull().sum() # this will show the number of null values in each column
# Out:
# App Name                  5
# App Id                    0
# Category                  0
# Rating                22883
# Rating Count          22883
# Installs                  0
# Minimum Installs        107
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size_in_bytes         74790
# Minimum Android        6530
# Developer Id             33
# Developer Website    760835
# Developer Email          31
# Released              71053
# Last Updated              0
# Content Rating            0
# Privacy Policy       420953
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# Size_in_Mb            74790
# Installs_category         0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False) # this will show the number of null values in each column in descending order
# Out:
# Developer Website    760835
# Privacy Policy       420953
# Size_in_Mb            74790
# Size_in_bytes         74790
# Released              71053
# Rating                22883
# Rating Count          22883
# Minimum Android        6530
# Currency                135
# Minimum Installs        107
# Developer Id             33
# Developer Email          31
# App Name                  5
# App Id                    0
# Price                     0
# Free                      0
# Maximum Installs          0
# Last Updated              0
# Content Rating            0
# Installs                  0
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# Category                  0
# Installs_category         0
# dtype: int64

# %%
df.isnull().sum().sum() # this will show the total number of null values in the dataframe
# Out:
# 1455028

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False) # this will show the percentage of null values in each column
# Out:
# Developer Website    32.894657
# Privacy Policy       18.199879
# Size_in_Mb            3.233541
# Size_in_bytes         3.233541
# Released              3.071972
# Rating                0.989345
# Rating Count          0.989345
# Minimum Android       0.282324
# Currency              0.005837
# Minimum Installs      0.004626
# Developer Id          0.001427
# Developer Email       0.001340
# App Name              0.000216
# App Id                0.000000
# Price                 0.000000
# Free                  0.000000
# Maximum Installs      0.000000
# Last Updated          0.000000
# Content Rating        0.000000
# Installs              0.000000
# Ad Supported          0.000000
# In App Purchases      0.000000
# Editors Choice        0.000000
# Scraped Time          0.000000
# Category              0.000000
# Installs_category     0.000000
# dtype: float64

# %%
# make a figure size
plt.figure(figsize=(16, 6))
#plot the null values in each column
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis') # this will show the heatmap of null values in the dataframe
# Out:
# <Axes: >

# %% [markdown]
# - There is another way, let's plot the missing values by percentage

# %%
# make figure size
plt.figure(figsize=(16, 6))
# plot the null values by their percentage in each column
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values in each Column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column')

# %% [markdown]
# - Let's plot the missing values other than 'Rating', 'Rating Count'Android' column
# - We have missing percentage columns other than rating having less than 5 percent of missing values, we will plot them as follows:

# %%
plt.figure(figsize=(16, 6)) # make figure size
missing_percentage[missing_percentage < 5].plot(kind='bar') # plot the null values by their percentage in each column
plt.xlabel('Columns') # add the x-axis labels
plt.ylabel('Percentage') # add the labels for y-axis
plt.title('Percentage of Missing Values in each Column without Rating column')  # add the title for the plot
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column without Rating column')

# %%
df.isnull().sum().sort_values(ascending=False) # this will show the number of null values in each column in descending order
# Out:
# Developer Website    760835
# Privacy Policy       420953
# Size_in_Mb            74790
# Size_in_bytes         74790
# Released              71053
# Rating                22883
# Rating Count          22883
# Minimum Android        6530
# Currency                135
# Minimum Installs        107
# Developer Id             33
# Developer Email          31
# App Name                  5
# App Id                    0
# Price                     0
# Free                      0
# Maximum Installs          0
# Last Updated              0
# Content Rating            0
# Installs                  0
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# Category                  0
# Installs_category         0
# dtype: int64

# %% [markdown]
# ## Observations:
# ---
# - we have 760835 missing values in `Developer Website` which is 32.894657% of the total values in the column.
# -
# - we have 420953 missing values in `Privacy Policy ` which is 18.199879% of the total values in the column.
#
# - We have 74790 missing values in the `'Size_in_bytes'` and `'Size_in_Mb'` columns, which is 3.233541% of the total values in the column.
# - we have 71053 missing values in `Released ` which is 3.071972% of the total values in the column.
#
#
# - We have 22883 missing values in the `'Rating' and 'Rating Count'` column, which is 0.989345% of the total values in the column.
#
# - We have 6530 missing value in the `'Minimum Android'` column, which is 0.282324% of the total values in the column.
# -
# - We have 135 missing values in the `'Currency'` column, which is 0.0058371% of the total values in the column.
# - We have 107 missing values in the `'Minimum Installs'` column, which is 0.004626% of the total values in the column.
# - We have 33 missing values in the `'Developer Id'` column, which is 0.001427% of the total values in the column.
# - - We have 31 missing values in the `'Developer Email'` column, which is 0.001340% of the total values in the column.
# - We have 5 missing values in the `'App Name'` column, which is 0.000216% of the total values in the column.
#
#
# ### **2.3. Dealing with the missing values**
# - We can not impute the `Rating` column as is is directly linked with the installation column. To test this Hypothesis we need to plot the `Rating` column with the `Installs` and `Size` columns and statistically test it using `pearson correlation test`.
# ---

# %% [markdown]
# - Let's run the correlations

# %%
df.describe() # these are numeric columns
# Out:
#              Rating  Rating Count      Installs  Minimum Installs  \
# count  2.290061e+06  2.290061e+06  2.312944e+06      2.312837e+06
# mean   2.203152e+00  2.864839e+03  1.834367e+05      1.834452e+05
# std    2.106223e+00  2.121626e+05  1.513109e+07      1.513144e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00  5.000000e+01      5.000000e+01
# 50%    2.900000e+00  6.000000e+00  5.000000e+02      5.000000e+02
# 75%    4.300000e+00  4.200000e+01  5.000000e+03      5.000000e+03
# max    5.000000e+00  1.385576e+08  1.000000e+10      1.000000e+10
#
#        Maximum Installs         Price  Size_in_bytes    Size_in_Mb
# count      2.312944e+06  2.312944e+06   2.238154e+06  2.238154e+06
# mean       3.202017e+05  1.034992e-01   2.013260e+07  1.919994e+01
# std        2.355495e+07  2.633127e+00   2.504606e+07  2.388578e+01
# min        0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# ...

# %%
# Make a correlation matrix of numeric columns
plt.figure(figsize=(16, 10)) # make figure size  
numeric_cols = ['Rating','Rating Count', 'Installs', 'Minimum Installs', 'Maximum Installs', 'Price', 'Size_in_Mb'] # make a list of numeric columns
sns.heatmap(df[numeric_cols].corr(), annot=True) # plnsot the correlation matrix
# Out:
# <Axes: >

# %%
# we can also calculate the correlation matrix using pandas
df[numeric_cols].corr() # this will show the correlation matrix
# Out:
#                     Rating  Rating Count  Installs  Minimum Installs  \
# Rating            1.000000      0.013038  0.011214          0.011214
# Rating Count      0.013038      1.000000  0.545281          0.545281
# Installs          0.011214      0.545281  1.000000          1.000000
# Minimum Installs  0.011214      0.545281  1.000000          1.000000
# Maximum Installs  0.012615      0.547571  0.954037          0.954037
# Price            -0.003674     -0.000411 -0.000461         -0.000461
# Size_in_Mb        0.054367      0.040374  0.033647          0.033652
#
#                   Maximum Installs     Price  Size_in_Mb
# Rating                    0.012615 -0.003674    0.054367
# Rating Count              0.547571 -0.000411    0.040374
# Installs                  0.954037 -0.000461    0.033647
# Minimum Installs          0.954037 -0.000461    0.033652
# Maximum Installs          1.000000 -0.000515    0.037687
# Price                    -0.000515  1.000000    0.003979
# ...

# %%
# we can calculate the pearson correlation coefficient using scipy as well as follows

# this is to install scipy if you have not done it before
# pip install scipy 
from scipy import stats

# remove rows containing NaN or infinite values (Important to calculate Pearson's R)
df_clean = df.dropna()

# calculate Pearson's R between Rating Count/Reviews and Installs
pearson_r, _ = stats.pearsonr(df_clean['Rating Count'], df_clean['Installs'])
print(f"Pearson's R between Rating Count and Installs: {pearson_r:.4f}")
# Out:
# Pearson's R between Rating Count and Installs: 0.5447

# %% [markdown]
# ---
# ## **Observations**
# - Lighter color shows the high correlation and darker color shows the low correlation
# - We can see that the `Rating Count(Reviews)` column has a high correlation with the `Installs` column, which is `0.55` according to corr(). Which is quite good.
#   - This shows that the more the Rating Count(Reviews) the more the installs are for one app. If in any case we need to impute Rating Count we have to think of number of install.
# - Installs is slightly correlated with `Size_in_Mb` or `Size_in_bytes` , which is `0.034`, this also shows us the importance of size and Installs. But we can not depend on it as the Peason correlation is very low.
# ---

# %% [markdown]
# - Before going ahead, Let's remove the rows with missing values in the  `'Minimum Android'` , `'Currency'`,`'Minimum Installs'` ,  `'Developer Id'` , `'Developer Email'` ,and  `'App Name'`  columns, as they are very less in number and will not affect our analysis.

# %%
# length before removing null values
print(f"Length of the dataframe before removing null values: {len(df)}")
# Out:
# Length of the dataframe before removing null values: 2312944

# %%
# Let's remove the rows with missing values in the  `'Minimum Android'` , `'Currency'`,`'Minimum Installs'` ,  `'Developer Id'` , `'Developer Email'` ,and  `'App Name'`  columns
df.dropna(subset=['Minimum Android', 'Currency', 'Minimum Installs', 'Developer Id', 'Developer Email','App Name'], inplace=True)

# %%
# length after removing null values
print(f"Length of the dataframe after removing null values: {len(df)}")
# Out:
# Length of the dataframe after removing null values: 2306210

# %%
2312944-2306210
# Out:
# 6734

# %% [markdown]
# - We have removed `6734` rows having null values in the   `'Minimum Android'` , `'Currency'`,`'Minimum Installs'` ,  `'Developer Id'` , `'Developer Email'` ,and  `'App Name'`  columns

# %%
# let's check the null values again
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer Website    758724
# Privacy Policy       419150
# Size_in_Mb            74600
# Size_in_bytes         74600
# Released              70765
# Rating                22763
# Rating Count          22763
# App Name                  0
# Developer Email           0
# Scraped Time              0
# Editors Choice            0
# In App Purchases          0
# Ad Supported              0
# Content Rating            0
# Last Updated              0
# Developer Id              0
# App Id                    0
# Minimum Android           0
# Currency                  0
# Price                     0
# Free                      0
# Maximum Installs          0
# Minimum Installs          0
# Installs                  0
# Category                  0
# Installs_category         0
# dtype: int64

# %% [markdown]
# ---
# ## **Observations**
# - Only `Developer Website`, `Privacy Policy`,  `Size_in_bytes` or `Size_in_Mb`,`Released`,`Rating` and `Rating Count`,  columns are left with missing values.
#   - We know that we have to be carefull while deadling with `Rating` column, as it is directly linked with the `Installs` column.
#   - In Size columns we already know about `Varies with device` values, which we have converted into null values, we do not need to impute at the moment, as every app has different size and nobody can predict that as nearly as possible.
# ---

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size_in_bytes', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time', 'Size_in_Mb', 'Installs_category'],
#       dtype='object')

# %%
# use groupby function to find the trend of Rating in each Installs_category
df.groupby('Installs_category')['Rating'].describe()
# Out:
#                         count      mean       std  min  25%  50%  75%  max
# Installs_category
# no                    11250.0  0.050720  0.457927  0.0  0.0  0.0  0.0  5.0
# Very low             427073.0  0.218303  1.008745  0.0  0.0  0.0  0.0  5.0
# Low                 1187964.0  2.023772  2.169482  0.0  0.0  0.0  4.4  5.0
# Moderate             397903.0  3.815589  0.982627  0.0  3.6  4.1  4.4  5.0
# More than moderate   184609.0  3.886217  0.785232  0.0  3.6  4.1  4.4  5.0
# High                  60406.0  4.013853  0.555542  0.0  3.8  4.1  4.4  5.0
# Very High             12746.0  4.142162  0.409284  0.0  4.0  4.2  4.4  5.0
# Top Notch              1496.0  4.237701  0.342540  1.1  4.1  4.3  4.4  4.9

# %% [markdown]
# # Replace the respective missing values of Rating, with respect to the average give in each 'Installs Category'!

# %%
df['Rating'].isnull().sum()
# Out:
# 22763

# %%
# in which Install_category the Rating has NaN values
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# Low                   9988
# Very low              9894
# Moderate              1725
# More than moderate     715
# no                     253
# High                   178
# Very High                9
# Top Notch                1
# Name: count, dtype: int64

# %%
# replace the NaN values in Rating with respect to installs category
df['Rating'].fillna(df.groupby('Installs_category')['Rating'].transform('mean'), inplace=True)

# %%
# check the replaced values in which Install_category the Rating has NaN values
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# no                    0
# Very low              0
# Low                   0
# Moderate              0
# More than moderate    0
# High                  0
# Very High             0
# Top Notch             0
# Name: count, dtype: int64

# %% [markdown]
# - Let's check if there is any similar link with Reviews as well

# %%
# in which Install_category the Rating Count(Reviews) has NaN values
df['Installs_category'].loc[df['Rating Count'].isnull()].value_counts().sum()
# Out:
# 22763

# %% [markdown]
# - There are 22763 Null values in Rating Count(Reviews)

# %%
# replace the NaN values in Rating Count with respect to installs category
df['Rating Count'].fillna(df.groupby('Installs_category')['Rating Count'].transform('mean'), inplace=True)

# %%
# check the replaced values in which Install_category the Rating Count has NaN values
df['Installs_category'].loc[df['Rating Count'].isnull()].value_counts()
# Out:
# Installs_category
# no                    0
# Very low              0
# Low                   0
# Moderate              0
# More than moderate    0
# High                  0
# Very High             0
# Top Notch             0
# Name: count, dtype: int64

# %%
# let's plot the same plots for Rating Count(Reviews) column
plt.figure(figsize=(16, 6)) # make figure size
sns.boxplot(x='Installs_category', y= 'Rating Count', data=df) # plot the boxplot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Rating Count'>

# %% [markdown]
# - The data looks really imbalance, let's normalize the data using log transformation

# %%
# let's plot the same plots for Rating Count(Reviews) column as well
plt.figure(figsize=(16, 6)) # make figure size
sns.boxplot(x='Installs_category', y= np.log10(df['Rating Count']), data=df) # plot the boxplot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Rating Count'>

# %% [markdown]
# - We also draw the scatter plot of the `Rating` and `Rating Count(Review)` columns with the `Installs` column

# %%
# Draw a scatter plot between Rating, Rating Count(Review)s and Installs
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Rating', y='Rating Count', hue='Installs_category', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Rating', ylabel='Rating Count'>

# %% [markdown]
# - It doesn't show any trend, because, you should know that Rating is a categorical variable (Ordinal) and Rating Count is a continuous variable, therefore, we can not plot them together.
# - Let's try with Rating Count and Installs

# %%
# plot Rating Count(reviews) and installs in a scatter plot
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Rating Count', y='Installs', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Rating Count', ylabel='Installs'>

# %% [markdown]
# - We did not see any trend and the issue is we need to normalize the data before plotting it, let's try with log transformation

# %%
# plot Rating Count(reviews) and installs in a scatter plot
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x=np.log10(df['Rating Count']), y=np.log10(df['Installs']), data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Rating Count', ylabel='Installs'>

# %% [markdown]
# - Now we see a slight trend but still the issue is installs were given in a factorial manner, as 10+, 20+, 1000+ etc, and these are not continuous number but Discreet one, therefore, we can only see a slight trends here. Let's plot a line plot to see the trend.

# %%
# plot Rating Count(reviews) and installs in a scatter plot with trend line
plt.figure(figsize=(16, 6)) # make figure size
sns.lmplot(x='Rating Count', y='Installs', data=df) # plot the scatter plot with trend line

# %% [markdown]
# - Here, we can see a nice trend, which shows that number of Rating count(Reviews) increases with the number of Installs, which is quite obvious.

# %% [markdown]
# ---
# ## **Observation**
# -We can see that most of the null values from `Rating` column are low - Moderate Installation apps, which make sense that if the app has less installations, it has less Rating and review.

# %% [markdown]
# - But wait, we have to check for the duplicates as well, as they can affect our analysis.

# %% [markdown]
# ## 2.3. **Duplicates**
#
# * Removing duplicates is one of the most important part of the data wrangling process, we must remove the duplicates in order to get the correct insights from the data.
# * If you do not remove duplicates from a dataset, it can lead to incorrect insights and analysis.
# * Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points.
# * It is important to remove duplicates to ensure the accuracy and reliability of your data analysis.

# %%
# find duplicate if any
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# This shows us zero duplicates, but we can also check based on the app name, as we know that every app has a unique name.

# %%
# find duplicate if any in the 'App Name' column
df['App Name'].duplicated().sum()
# Out:
# 134583

# %% [markdown]
# - Oops! we have 134583 dupicate app names
# - Can we find a column which can help us to remove the duplicates?
#
# let's check for number of duplicates in each column using a for loop and printing the output

# %%
# let's check for number of duplicates
for col in df.columns:
    print(f"Number of duplicates in {col} column are: {df[col].duplicated().sum()}")
# Out:
# Number of duplicates in App Name column are: 134583
# Number of duplicates in App Id column are: 0
# Number of duplicates in Category column are: 2306162
# Number of duplicates in Rating column are: 2306160
# Number of duplicates in Rating Count column are: 2267751
# Number of duplicates in Installs column are: 2306188
# Number of duplicates in Minimum Installs column are: 2306188
# Number of duplicates in Maximum Installs column are: 2054922
# Number of duplicates in Free column are: 2306208
# Number of duplicates in Price column are: 2305149
# Number of duplicates in Currency column are: 2306195
# Number of duplicates in Size_in_bytes column are: 2304564
# Number of duplicates in Minimum Android column are: 2306056
# Number of duplicates in Developer Id column are: 1550540
# Number of duplicates in Developer Website column are: 1498868
# Number of duplicates in Developer Email column are: 1359391
# Number of duplicates in Released column are: 2302051
# ...

# %% [markdown]
# This means that the only better way to find duplicates is to check for whole data

# %%
# print the number of duplicates in df
print(f"Number of duplicates in df are: {df.duplicated().sum()}")
# Out:
# Number of duplicates in df are: 0

# %% [markdown]
# - Find and watch all duplicates if they are real!

# %%
# find exact duplicates and print them
# df[df['App Name'].duplicated(keep=False)].sort_values(by='App Name')

# %% [markdown]
# - Remove Duplicates

# %%
# remove the duplicates
df.drop_duplicates(inplace=True)

# %%
# print the number of rows and columns after removing duplicates
print(f"Number of rows after removing duplicates: {df.shape[0]}")
# Out:
# Number of rows after removing duplicates: 2306210

# %%
2312944-2306210
# Out:
# 6734

# %% [markdown]
# - Now we have removed 6734 duplicates from the dataset. and have 2306210 rows left.
#
# ---

# %% [markdown]
# ## **3. Insights from Data**

# %% [markdown]
# ## **3.1. Which category has the highest number of apps?**

# %%
# which category has highest number of apps
df['Category'].value_counts().head(10) # this will show the top 10 categories with highest number of apps
# Out:
# Category
# Education            240540
# Music & Audio        154696
# Tools                143374
# Business             143237
# Entertainment        137969
# Lifestyle            118152
# Books & Reference    116574
# Personalization       88980
# Health & Fitness      83248
# Productivity          79297
# Name: count, dtype: int64

# %% [markdown]
# # **3.2. Which category has the highest number of installs?**

# %%
# category with highest number of Installs
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# Tools                      69880094717
# Communication              42984286926
# Productivity               28211563067
# Photography                18951267722
# Video Players & Editors    18588930348
# Action                     17396224099
# Social                     17165579753
# Entertainment              17095934352
# Casual                     16836361480
# Arcade                     14498416372
# Name: Installs, dtype: int64

# %% [markdown]
# # **3.3. Which category has the highest number of reviews?**

# %%
# Category with highest number of Reviews
df.groupby('Category')['Rating Count'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# Action                     5.585889e+08
# Tools                      4.720543e+08
# Social                     4.704005e+08
# Communication              4.701570e+08
# Casual                     3.601423e+08
# Video Players & Editors    2.651309e+08
# Arcade                     2.452191e+08
# Strategy                   2.334072e+08
# Simulation                 2.310301e+08
# Entertainment              2.252095e+08
# Name: Rating Count, dtype: float64

# %% [markdown]
# # **3.4. Which category has the highest rating?**

# %%
# Category with highest average Rating
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# Role Playing               3.350390
# Casino                     3.273871
# Simulation                 3.195436
# Weather                    3.105665
# Card                       3.071740
# Racing                     2.948356
# Video Players & Editors    2.899227
# Word                       2.885834
# Comics                     2.857320
# Strategy                   2.856834
# Name: Rating, dtype: float64

# %%
# plot the rating distribution
plt.figure(figsize=(16, 6)) # make figure size
sns.kdeplot(df['Rating'], color="blue", shade=True) # plot the distribution plot
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count  Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0        10
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0      5000
# 2        com.doantiepvien.crm   Productivity     0.0           0.0        50
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0        10
# 4        com.horodyski.grower          Tools     0.0           0.0       100
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size_in_bytes  \
# 0              10.0                15  True    0.0      USD     10485760.0
# ...

# %%
# plot number of installs for free vs paid apps make a bar plot
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='Price', y='Installs', data=df) # plot the bar plot
# Out:
# <Axes: xlabel='Price', ylabel='Installs'>

# %%
# show scatter plot as well where x-axis is Installs and y-axis is Price and hue is Type
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Installs', y='Price', hue='Free', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Installs', ylabel='Price'>

# %%
# Check if there is any impact of size on installs
# make a bar plot of Size_in_Mb vs Installs_category
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='Installs_category', y='Size_in_Mb', data=df) # plot the bar plot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Size_in_Mb'>

# %%
# Which content rating is most popular in installs
df['Content Rating'].value_counts() # this will show the value counts of each content rating
# Out:
# Content Rating
# Everyone           2016058
# Teen                195967
# Mature 17+           60133
# Everyone 10+         33764
# Unrated                154
# Adults only 18+        134
# Name: count, dtype: int64

# %%
# plot the bar plot of Content Rating vs Installs
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='Content Rating', y='Installs', data=df) # plot the bar plot
# Out:
# <Axes: xlabel='Content Rating', ylabel='Installs'>

# %%
# find how many apps are there in Everyone content rating
df['Category'].loc[df['Content Rating'] == 'Everyone'].value_counts()
# Out:
# Category
# Education                  231644
# Tools                      139051
# Business                   136233
# Entertainment              111906
# Music & Audio              109863
# Lifestyle                  106170
# Books & Reference          104851
# Health & Fitness            79048
# Productivity                77310
# Personalization             73850
# Shopping                    68748
# Food & Drink                67468
# Finance                     63742
# Travel & Local              63071
# Puzzle                      47710
# Arcade                      47048
# Casual                      44469
# Sports                      42308
# Communication               38885
# News & Magazines            36126
# Photography                 33022
# Medical                     30013
# Maps & Navigation           24778
# Educational                 20537
# Simulation                  17814
# Auto & Vehicles             17314
# Art & Design                16781
# ...

# %%
# plot top 5 rated paid apps
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='App Name', y='Rating', data=df[df['Price'] > 0.0].sort_values(by='Rating', ascending=False).head(5)) # plot the bar plot
# Out:
# <Axes: xlabel='App Name', ylabel='Rating'>

# %%
# find top 5 free apps

df[df['Price'] == 0.0].sort_values(by='Rating', ascending=False).head(5)
# Out:
#                                           App Name  \
# 2312943               Biliyor Musun - Sonsuz Yarış
# 1247774                                Herbanation
# 1247932                                  WHAT'SOUP
# 1247907                          Bang Wijay Mobile
# 1247903  مكتبة الأربعين النووية - سبعة كتب بدون نت
#
#                                 App Id           Category  Rating  \
# 2312943      com.yyazilim.biliyormusun             Trivia     5.0
# 1247774         com.fanyan_herbanation           Shopping     5.0
# 1247932        com.app_whatsoup.layout       Food & Drink     5.0
# 1247907  com.bangwijay.webviewstandart          Education     5.0
# 1247903     so.ateya.ahmed.Nawawy40_BN  Books & Reference     5.0
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# 2312943          12.0       100             100.0               354  True
# 1247774           6.0        50              50.0                63  True
# ...

# %%
# plot top rated 5 apps in free category
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='App Name', y='Rating', data=df[df['Price'] == 0.0].sort_values(by='Rating', ascending=False).head(5)) # plot the bar plot
# Out:
# <Axes: xlabel='App Name', ylabel='Rating'>

# %%
df[df['Price'] == 0.0].sort_values(by='Rating', ascending=False).head(5) # find top 5 free apps
# Out:
#                                           App Name  \
# 2312943               Biliyor Musun - Sonsuz Yarış
# 1247774                                Herbanation
# 1247932                                  WHAT'SOUP
# 1247907                          Bang Wijay Mobile
# 1247903  مكتبة الأربعين النووية - سبعة كتب بدون نت
#
#                                 App Id           Category  Rating  \
# 2312943      com.yyazilim.biliyormusun             Trivia     5.0
# 1247774         com.fanyan_herbanation           Shopping     5.0
# 1247932        com.app_whatsoup.layout       Food & Drink     5.0
# 1247907  com.bangwijay.webviewstandart          Education     5.0
# 1247903     so.ateya.ahmed.Nawawy40_BN  Books & Reference     5.0
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# 2312943          12.0       100             100.0               354  True
# 1247774           6.0        50              50.0                63  True
# ...

# %%
# Plot top 5 FREE apps with highest number of reviews
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='App Name', y='Rating Count', data=df[df['Price'] == 0.0].sort_values(by='Rating Count', ascending=False).head(5)) # plot the bar plot
# Out:
# <Axes: xlabel='App Name', ylabel='Rating Count'>

# %%
df[df['Price'] == 0.0].sort_values(by='Rating Count', ascending=False).head(5)
# Out:
#                            App Name                      App Id  \
# 385470           WhatsApp Messenger                com.whatsapp
# 304824                    Instagram       com.instagram.android
# 2222701                    Facebook         com.facebook.katana
# 881403                      YouTube  com.google.android.youtube
# 244319   Garena Free Fire - Rampage          com.dts.freefireth
#
#                         Category  Rating  Rating Count    Installs  \
# 385470             Communication     4.0   138557570.0  5000000000
# 304824                    Social     3.8   120206190.0  1000000000
# 2222701                   Social     2.3   117850066.0  5000000000
# 881403   Video Players & Editors     4.4   112440547.0  5000000000
# 244319                    Action     4.2    89177097.0   500000000
#
#          Minimum Installs  Maximum Installs  Free  Price Currency  \
# 385470       5.000000e+09        6265637751  True    0.0      USD
# ...

# %%
# Plot top 5 Paid apps with highest number of reviews
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='App Name', y='Rating Count', data=df[df['Price'] > 0.0].sort_values(by='Rating Count', ascending=False).head(5)) # plot the bar plot
# Out:
# <Axes: xlabel='App Name', ylabel='Rating Count'>
