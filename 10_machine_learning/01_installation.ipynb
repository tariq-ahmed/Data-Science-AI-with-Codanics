# %% [markdown]
# # Steps:
# 1. Creata a new conda environment `python_ml`
# 2. install the following packages:
#    1. python conda install python
#       1. pandas
#       2. numpy
#       3. matplotlib
#       4. seaborn
#       5. scipy
#       6. scikit-learn
#       7. jupyter
#       8. openpyxl
#       9. plotly
#
#
# pip install pandas numpy matplotlib seaborn scipy scikit-learn jupyter openpyxl plotly

# %%
pip install pandas numpy matplotlib seaborn scipy scikit-learn jupyter openpyxl plotly
# Out:
# Requirement already satisfied: pandas in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (2.0.1)
# Collecting matplotlib
#   Using cached matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (1.14.0)
# Requirement already satisfied: scikit-learn in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (1.5.1)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Requirement already satisfied: openpyxl in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (3.1.5)
# Requirement already satisfied: plotly in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (5.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from scikit-learn) (3.5.0)
# Collecting notebook (from jupyter)
#   Using cached notebook-7.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter)
#   Using cached qtconsole-5.5.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter) (6.28.0)
# Collecting ipywidgets (from jupyter)
#   Using cached ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: et-xmlfile in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-console->jupyter) (3.0.43)
# Requirement already satisfied: pygments in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-console->jupyter) (2.15.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbconvert->jupyter) (1.3.0)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook->jupyter)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.3,>=4.2.0 (from notebook->jupyter)
#   Using cached jupyterlab-4.2.4-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.11.0)
# Requirement already satisfied: colorama in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: overrides>=5.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab<4.3,>=4.2.0->notebook->jupyter)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.3,>=4.2.0->notebook->jupyter)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (72.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests>=2.31 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (24.1.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.19.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.2.2)
# Requirement already satisfied: executing in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\tariq\anaconda3\envs\python_ml\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Using cached matplotlib-3.9.0-cp311-cp311-win_amd64.whl (8.0 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Using cached ipywidgets-8.1.3-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached notebook-7.2.1-py3-none-any.whl (5.0 MB)
# Using cached qtconsole-5.5.2-py3-none-any.whl (123 kB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab-4.2.4-py3-none-any.whl (11.6 MB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Installing collected packages: matplotlib, jupyter-server-terminals, jsonschema-specifications, httpx, argon2-cffi-bindings, seaborn, jsonschema, isoduration, argon2-cffi, nbformat, ipywidgets, qtconsole, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 httpx-0.27.0 ipywidgets-8.1.3 isoduration-20.11.0 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.4 jupyterlab-server-2.27.3 matplotlib-3.9.0 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.2.1 notebook-shim-0.2.4 qtconsole-5.5.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
reg.coef_
# Out:
# array([0.5, 0.5])
