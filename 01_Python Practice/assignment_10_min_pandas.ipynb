# %%
import numpy as np
import pandas as pd

s = pd.Series([1,3,5,np.nan,6,8])


# Creating a DataFrame by 
# passing a NumPy array with a datetime index using date_range() and labeled columns:

dates = pd.date_range("20231101", periods=6)    # date_range() is used to generate date time index

dates
# Out:
# DatetimeIndex(['2023-11-01', '2023-11-02', '2023-11-03', '2023-11-04',
#                '2023-11-05', '2023-11-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-11-01 -0.399028 -0.625801  0.173606  0.422349
# 2023-11-02  1.112491 -1.309168  0.748258 -0.280926
# 2023-11-03  0.519989 -0.842507  0.260964 -1.583100
# 2023-11-04 -0.528895  1.121021 -0.515521 -0.671983
# 2023-11-05 -0.162345 -0.888862 -0.915570  1.361531
# 2023-11-06  0.439550  0.880225  0.088548  0.577875

# %%
df2 = pd.DataFrame(
    { "A" : 1.0, # A is a column name
    "B" : pd.Timestamp("20231101"), # B is a column name
    "C" : pd.Series(1, index =list(range(4)), dtype = "float32"), # C is a column name
    " D" : np.array([3] * 4, dtype = "int32"), # D is a column name
    "E" : pd.Categorical(["test", "train", "test", "train"]), # E is a column name
    "F" : "foo", # F is a column name
    }

)

df2
# Out:
#      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo

# %%
df2.dtypes # dtypes is used to check the data type of each column
# Out:
# A           float64
# B     datetime64[s]
# C           float32
#  D            int32
# E          category
# F            object
# dtype: object

# %%
df2.A # A is a column name
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df2.abs , # abs is used to get the absolute value of each element.
# Out:
# (<bound method NDFrame.abs of      A          B    C   D      E    F
#  0  1.0 2023-11-01  1.0   3   test  foo
#  1  1.0 2023-11-01  1.0   3  train  foo
#  2  1.0 2023-11-01  1.0   3   test  foo
#  3  1.0 2023-11-01  1.0   3  train  foo>,)

# %%
df2.add # add is used to add two dataframes
# Out:
# <bound method DataFrame.add of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.add_prefix # add_prefix is used to add a prefix to each column name
# Out:
# <bound method NDFrame.add_prefix of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.add_suffix # add_suffix is used to add a suffix to each column name
# Out:
# <bound method NDFrame.add_suffix of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.align # align is used to align two dataframes on a particular axis
# Out:
# <bound method NDFrame.align of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.all # .all is used to check if all elements are True or not along the specified axis
# Out:
# <bound method DataFrame.all of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.any # .any is used to check if any element is True or not along the specified axis
# Out:
# <bound method DataFrame.any of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.append # .append is used to append rows of other to the end of caller, returning a new object.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15704\786045445.py in ?()
# ----> 1 df2.append # .append is used to append rows of other to the end of caller, returning a new object.
#
# c:\Users\Tariq\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df2.apply # apply is used to apply a function along an axis of the DataFrame.
# Out:
# <bound method DataFrame.apply of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.A          # A is a column name, so it will return the column A         
df2.bool      # bool is used to return the bool of a single element PandasObject.
df2.abs       # abs is used to get the absolute value of each element.
df2.boxplot  # boxplot is used to make a box plot from DataFrame columns.
df2.add     # add is used to add two dataframes               
df2.C       # C is a column name, so it will return the column C
df2.add_prefix   # add_prefix is used to add a prefix to each column name       
df2.clip        # clip is used to trim values at input threshold(s).
df2.add_suffix         # add_suffix is used to add a suffix to each column name 
df2.columns           # columns is used to get the column labels of the DataFrame.
df2.align              # align is used to align two dataframes on a particular axis 
df2.copy             # copy is used to make a copy of this object’s indices and data.
df2.all                 # .all is used to check if all elements are True or not along the specified axis 
df2.count             # count is used to count non-NA cells for each column or row.
df2.any                 # .any is used to check if any element is True or not along the specified axis
df2.combine          # combine is used to combine with another DataFrame, aligning on the index
df2.append       # .append is used to append rows of other to the end of caller, returning a new object.       
df2.D            # D is a column name, so it will return the column D
df2.apply           # apply is used to apply a function along an axis of the DataFrame.      
df2.describe     # describe is used to generate descriptive statistics.
df2.applymap       # applymap is used to apply a function to a Dataframe elementwise.     
df2.diff         # diff is used to find the first discrete difference of objects.
df2.B              # B is a column name, so it will return the column B     
df2.duplicated  # duplicated is used to return boolean Series denoting duplicate rows.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3224\2228256674.py in ?()
#      13 df2.all                 # .all is used to check if all elements are True or not along the specified axis
#      14 df2.count             # count is used to count non-NA cells for each column or row.
#      15 df2.any                 # .any is used to check if any element is True or not along the specified axis
#      16 df2.combine          # combine is used to combine with another DataFrame, aligning on the index
# ---> 17 df2.append       # .append is used to append rows of other to the end of caller, returning a new object.
#      18 df2.D            # D is a column name, so it will return the column D
#      19 df2.apply           # apply is used to apply a function along an axis of the DataFrame.
# ...

# %%
df2.boxplot
# Out:
# <bound method boxplot_frame of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.head # head is used to return the first n rows.
# Out:
# <bound method NDFrame.head of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.tail(3) # tail is used to return the last n rows.
# Out:
#      A          B    C   D      E    F
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo

# %%
df2.index  # index is used to get the index (row labels) of the DataFrame.
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
#  if i want to check the index of the dataframe, row 1 to row 4, then i will use the following code
df2.index[0:4]
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns # columns is used to get the column labels of the DataFrame.
# Out:
# Index(['A', 'B', 'C', ' D', 'E', 'F'], dtype='object')

# %%
df2.to_numpy # to_numpy is used to convert the DataFrame to a NumPy array. this is a very important function in pandas as it is used to convert the dataframe to numpy array which is used in machine learning. numpy is a very important library in machine learning. numpy is used to perform mathematical operations on the data.
# Out:
# <bound method DataFrame.to_numpy of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df2.dtypes # dtypes is used to check the data type of each column
# Out:
# A           float64
# B     datetime64[s]
# C           float32
#  D            int32
# E          category
# F            object
# dtype: object

# %%
df2.to_numpy # to_numpy is used to convert the DataFrame to a NumPy array.
# Out:
# <bound method DataFrame.to_numpy of      A          B    C   D      E    F
# 0  1.0 2023-11-01  1.0   3   test  foo
# 1  1.0 2023-11-01  1.0   3  train  foo
# 2  1.0 2023-11-01  1.0   3   test  foo
# 3  1.0 2023-11-01  1.0   3  train  foo>

# %%
df.to_numpy # to_numpy is used to convert the DataFrame to a NumPy array.
# Out:
# <bound method DataFrame.to_numpy of                    A         B         C         D
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121
# 2023-11-06  0.042834  0.720971  0.358602  0.326814>

# %%
df.describe() # describe is used to generate descriptive statistics.
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.057654 -0.103841 -0.083808  0.066441
# std    1.078533  1.137871  0.545059  0.917774
# min   -1.853771 -2.303741 -0.661949 -1.029121
# 25%   -0.426003 -0.163696 -0.557587 -0.651409
# 50%    0.052347  0.340370 -0.111106  0.062840
# 75%    0.606334  0.543119  0.279522  0.647606
# max    1.197608  0.720971  0.677995  1.349054

# %%
df
# Out:
#                    A         B         C         D
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df.T # T is used to transpose index and columns. this is a very important function in pandas as it is used to transpose the dataframe. transpose is used to convert rows to columns and columns to rows. this is a very important function in pandas as it is used to convert the dataframe to numpy array which is used in machine learning.
# Out:
#    2023-11-01  2023-11-02  2023-11-03  2023-11-04  2023-11-05  2023-11-06
# A    0.061859    1.197608    0.787825   -0.582283   -1.853771    0.042834
# B    0.345683   -0.329948    0.608932   -2.303741    0.335057    0.720971
# C    0.677995   -0.264491    0.042280   -0.655285   -0.661949    0.358602
# D    1.349054    0.754536   -0.801500   -0.201135   -1.029121    0.326814

# %%
df # df is a dataframe name
# Out:
#                    A         B         C         D
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df.sort_index(axis=1, ascending=False) # this code is used to sort the dataframe by index. axis=1 means sort by column and axis=0 means sort by row. ascending=false means sort in descending order. ascending=true means sort in ascending order. this is a very important function in pandas as it is used to sort the dataframe by index. axis=1 means sort by column and axis=0 means sort by row. ascending=false means sort in descending order. ascending=true means sort in ascending order. this is a very important function in pandas as it is used to sort the dataframe by index. axis=1 means sort by column and axis=0 means sort by row. ascending=false means sort in descending order. ascending=true means sort in ascending order. this is a very important function in pandas as it is used to sort the dataframe by index. axis=1 means sort by column and axis=0 means sort by row. ascending=false means sort in descending order. ascending=true means sort in ascending order.
# Out:
#                    D         C         B         A
# 2023-11-01  1.349054  0.677995  0.345683  0.061859
# 2023-11-02  0.754536 -0.264491 -0.329948  1.197608
# 2023-11-03 -0.801500  0.042280  0.608932  0.787825
# 2023-11-04 -0.201135 -0.655285 -2.303741 -0.582283
# 2023-11-05 -1.029121 -0.661949  0.335057 -1.853771
# 2023-11-06  0.326814  0.358602  0.720971  0.042834

# %%
df.sort_values(by = "B") # sort by values of column B in ascending order
# Out:
#                    A         B         C         D
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df["A"] # A is a column name, so it will return the column A
# Out:
# 2023-11-01    0.061859
# 2023-11-02    1.197608
# 2023-11-03    0.787825
# 2023-11-04   -0.582283
# 2023-11-05   -1.853771
# 2023-11-06    0.042834
# Freq: D, Name: A, dtype: float64

# %%
df[0:3] # this code is used to get the first 3 rows of the dataframe
# Out:
#                    A         B         C         D
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500

# %%
df["20231102":"20231104"] # this code is used to get the rows from 20231102 to 20231104
# Out:
#                    A         B         C         D
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135

# %%
df.loc[dates[0]] # this code is used to get the first row of the dataframe
# Out:
# A    0.061859
# B    0.345683
# C    0.677995
# D    1.349054
# Name: 2023-11-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]] # this code is used to get all the rows of columns A and B
# Out:
#                    A         B
# 2023-11-01  0.061859  0.345683
# 2023-11-02  1.197608 -0.329948
# 2023-11-03  0.787825  0.608932
# 2023-11-04 -0.582283 -2.303741
# 2023-11-05 -1.853771  0.335057
# 2023-11-06  0.042834  0.720971

# %%
df.loc["20231102" : "20231104", ["A", "B"]] # this code is used to get the rows from 20231102 to 20231104 of columns A and B
# Out:
#                    A         B
# 2023-11-02  1.197608 -0.329948
# 2023-11-03  0.787825  0.608932
# 2023-11-04 -0.582283 -2.303741

# %%
df.loc[dates[0] , "A"] # this code is used to get the first row of column A
# Out:
# 0.061859243630415874

# %%
df.at[dates[0], "A"] # this code is used to get the first row of column A
# Out:
# 0.061859243630415874

# %%
df.iloc[3] # this code is used to get the 4th row of the dataframe
# Out:
# A   -0.582283
# B   -2.303741
# C   -0.655285
# D   -0.201135
# Name: 2023-11-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2] # this code is used to get the rows from 3 to 5 and columns from 0 to 2
# Out:
#                    A         B
# 2023-11-04 -0.582283 -2.303741
# 2023-11-05 -1.853771  0.335057

# %%
df.iloc[[1,2,4], [0,2]] # this code is used to get the rows 1, 2 and 4 and columns 0 and 2
# Out:
#                    A         C
# 2023-11-02  1.197608 -0.264491
# 2023-11-03  0.787825  0.042280
# 2023-11-05 -1.853771 -0.661949

# %%
df.iloc[1:3, :] # this code is used to get the rows from 1 to 3 and all columns
# Out:
#                    A         B         C         D
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500

# %%
df.iloc[:, 1:3] # this code is used to get all rows and columns from 1 to 3
# Out:
#                    B         C
# 2023-11-01  0.345683  0.677995
# 2023-11-02 -0.329948 -0.264491
# 2023-11-03  0.608932  0.042280
# 2023-11-04 -2.303741 -0.655285
# 2023-11-05  0.335057 -0.661949
# 2023-11-06  0.720971  0.358602

# %%
df.iloc[1,1] # this code is used to get the 2nd row and 2nd column
# Out:
# -0.3299475851991795

# %%
df.iat[1,1] # this code is used to get the 2nd row and 2nd column
# Out:
# -0.3299475851991795

# %%
df[df["A"] > 0 ] # this code is used to get all the rows where column A is greater than 0
# Out:
#                    A         B         C         D
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df[df>0] # this code is used to get all the rows where all the columns are greater than 0
# Out:
#                    A         B         C         D
# 2023-11-01  0.061859  0.345683  0.677995  1.349054
# 2023-11-02  1.197608       NaN       NaN  0.754536
# 2023-11-03  0.787825  0.608932  0.042280       NaN
# 2023-11-04       NaN       NaN       NaN       NaN
# 2023-11-05       NaN  0.335057       NaN       NaN
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df2 = df.copy() # this code is used to copy the dataframe, df.copy is used to make a copy of this object’s indices and data.

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"] # this code is used to add a new column E to the dataframe

# %%
df2 # df2 is a dataframe name
# Out:
#                    A         B         C         D      E
# 2023-11-01  0.061859  0.345683  0.677995  1.349054    one
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536    one
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500    two
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135  three
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121   four
# 2023-11-06  0.042834  0.720971  0.358602  0.326814  three

# %%
df2[df2["E"].isin(["two" , "four"]) ] # this code is used to get all the rows where column E is two or four
# Out:
#                    A         B         C         D     E
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500   two
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121  four

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range("20231105", periods=6)) # this code is used to create a series s1 with index as date range from 20231105 to 20231110 and values as 1,2,3,4,5,6

# %%
s1 # s1 is a series name
# Out:
# 2023-11-05    1
# 2023-11-06    2
# 2023-11-07    3
# 2023-11-08    4
# 2023-11-09    5
# 2023-11-10    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0 # this code is used to set the value of first row and column A to 0.

# %%
df
# Out:
#                    A         B         C         D
# 2023-11-01  0.000000  0.345683  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df.iat[0,1] = 0 # this code is used to set the value of first row and column B to 0.

# %%
df
# Out:
#                    A         B         C         D
# 2023-11-01  0.000000  0.000000  0.677995  1.349054
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121
# 2023-11-06  0.042834  0.720971  0.358602  0.326814

# %%
df.loc[:,"D"] = np.array([5] * len(df)) # this code is used to set the value of all rows and column D to 5.

# %%
df
# Out:
#                    A         B         C    D
# 2023-11-01  0.000000  0.000000  0.677995  5.0
# 2023-11-02  1.197608 -0.329948 -0.264491  5.0
# 2023-11-03  0.787825  0.608932  0.042280  5.0
# 2023-11-04 -0.582283 -2.303741 -0.655285  5.0
# 2023-11-05 -1.853771  0.335057 -0.661949  5.0
# 2023-11-06  0.042834  0.720971  0.358602  5.0

# %%
df2
# Out:
#                    A         B         C         D      E
# 2023-11-01  0.061859  0.345683  0.677995  1.349054    one
# 2023-11-02  1.197608 -0.329948 -0.264491  0.754536    one
# 2023-11-03  0.787825  0.608932  0.042280 -0.801500    two
# 2023-11-04 -0.582283 -2.303741 -0.655285 -0.201135  three
# 2023-11-05 -1.853771  0.335057 -0.661949 -1.029121   four
# 2023-11-06  0.042834  0.720971  0.358602  0.326814  three

# %%
df2 = df.copy() # this code is used to copy the dataframe, df.copy is used to make a copy of this object’s indices and data.

# %%
df2
# Out:
#                    A         B         C    D
# 2023-11-01  0.000000  0.000000  0.677995  5.0
# 2023-11-02  1.197608 -0.329948 -0.264491  5.0
# 2023-11-03  0.787825  0.608932  0.042280  5.0
# 2023-11-04 -0.582283 -2.303741 -0.655285  5.0
# 2023-11-05 -1.853771  0.335057 -0.661949  5.0
# 2023-11-06  0.042834  0.720971  0.358602  5.0

# %%
df2[df2>0] = -df2 # this code is used to set the value of all rows and columns to -df2 where df2 is greater than 0.

# %%
df2
# Out:
#                    A         B         C    D
# 2023-11-01  0.000000  0.000000 -0.677995 -5.0
# 2023-11-02 -1.197608 -0.329948 -0.264491 -5.0
# 2023-11-03 -0.787825 -0.608932 -0.042280 -5.0
# 2023-11-04 -0.582283 -2.303741 -0.655285 -5.0
# 2023-11-05 -1.853771 -0.335057 -0.661949 -5.0
# 2023-11-06 -0.042834 -0.720971 -0.358602 -5.0

# %%
df1 = df.reindex(index=dates[0:4] , columns=list(df.columns) + ["F"] ) # this code is used to create a dataframe df1 with index as first 4 rows of dates and columns as all the columns of df and a new column E
df1.loc[dates[0]:dates[1], "F"] = 1 # this code is used to set the value of first 2 rows of column F to 1

# %%
df1
# Out:
#                    A         B         C    D    E    F
# 2023-11-01  0.000000  0.000000  0.677995  5.0  1.0  1.0
# 2023-11-02  1.197608 -0.329948 -0.264491  5.0  1.0  1.0
# 2023-11-03  0.787825  0.608932  0.042280  5.0  NaN  NaN
# 2023-11-04 -0.582283 -2.303741 -0.655285  5.0  NaN  NaN

# %%
df1
# Out:
#                    A         B         C    D    E    F
# 2023-11-01  0.000000  0.000000  0.677995  5.0  1.0  1.0
# 2023-11-02  1.197608 -0.329948 -0.264491  5.0  1.0  1.0
# 2023-11-03  0.787825  0.608932  0.042280  5.0  NaN  NaN
# 2023-11-04 -0.582283 -2.303741 -0.655285  5.0  NaN  NaN

# %%
df1.dropna(how="any") # this code is used to drop all the rows which have any missing values
# Out:
#                    A         B         C    D    E    F
# 2023-11-01  0.000000  0.000000  0.677995  5.0  1.0  1.0
# 2023-11-02  1.197608 -0.329948 -0.264491  5.0  1.0  1.0

# %%
df1.fillna(value=5) # this code is used to fill all the missing values with 5
# Out:
#                    A         B         C    D    E    F
# 2023-11-01  0.000000  0.000000  0.677995  5.0  1.0  1.0
# 2023-11-02  1.197608 -0.329948 -0.264491  5.0  1.0  1.0
# 2023-11-03  0.787825  0.608932  0.042280  5.0  5.0  5.0
# 2023-11-04 -0.582283 -2.303741 -0.655285  5.0  5.0  5.0

# %%
pd.isna(df1) # this code is used to check if there are any missing values in the dataframe
# Out:
#                 A      B      C      D      E      F
# 2023-11-01  False  False  False  False  False  False
# 2023-11-02  False  False  False  False  False  False
# 2023-11-03  False  False  False  False   True   True
# 2023-11-04  False  False  False  False   True   True

# %%
df.mean() # this code is used to get the mean of all the columns
# Out:
# A   -0.067964
# B   -0.161455
# C   -0.083808
# D    5.000000
# E    1.000000
# dtype: float64

# %%
df.mean(axis=1) # this code is used to get the mean of all the rows
# Out:
# 2023-11-01    1.335599
# 2023-11-02    1.320634
# 2023-11-03    1.609759
# 2023-11-04    0.364673
# 2023-11-05    0.704834
# 2023-11-06    1.530602
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2) # this code is used to create a series s with index as dates and values as 1,3,5,np.nan,6,8 and shift the values by 2

s
# Out:
# 2023-11-01    NaN
# 2023-11-02    NaN
# 2023-11-03    1.0
# 2023-11-04    3.0
# 2023-11-05    5.0
# 2023-11-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index") # this code is used to subtract the values of series s from the dataframe df
# Out:
#                    A         B         C    D   E
# 2023-11-01       NaN       NaN       NaN  NaN NaN
# 2023-11-02       NaN       NaN       NaN  NaN NaN
# 2023-11-03 -0.212175 -0.391068 -0.957720  4.0 NaN
# 2023-11-04 -3.582283 -5.303741 -3.655285  2.0 NaN
# 2023-11-05 -6.853771 -4.664943 -5.661949  0.0 NaN
# 2023-11-06       NaN       NaN       NaN  NaN NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6) # this code is used to apply a function to the dataframe df
# Out:
# A    -0.380599
# B    -0.904147
# C    -0.469325
# D    28.000000
# E     5.600000
# dtype: float64

# %%
df.transform(lambda x:x*101.2)  # this code is used to apply a function to the dataframe df
# Out:
#                      A           B          C      D      E
# 2023-11-01    0.000000    0.000000  68.613127  506.0  101.2
# 2023-11-02  121.197978  -33.390696 -26.766536  506.0  101.2
# 2023-11-03   79.727936   61.623876   4.278740  506.0    NaN
# 2023-11-04  -58.927006 -233.138608 -66.314844  506.0    NaN
# 2023-11-05 -187.601597   33.907797 -66.989211  506.0    NaN
# 2023-11-06    4.334844   72.962271  36.290535  506.0    NaN

# %%
s = pd.Series(np.random.randint(0, 7, size=10)) # this code is used to create a series s with values as random integers from 0 to 7 and size as 10
s
# Out:
# 0    4
# 1    3
# 2    1
# 3    5
# 4    3
# 5    6
# 6    4
# 7    1
# 8    2
# 9    1
# dtype: int32

# %%
s.value_counts() # this code is used to get the count of each value in the series s
# Out:
# 1    3
# 4    2
# 3    2
# 5    1
# 6    1
# 2    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A","B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"]) # this code is used to create a series s with values as A,B,C,Aaba,Baca,np.nan,CABA,dog,cat
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower() # this code is used to convert all the values of series s to lower case
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4)) # this code is used to create a dataframe df with random values
df
# Out:
#           0         1         2         3
# 0  0.369137  0.872269 -0.847942 -0.924365
# 1 -0.547641  1.301120 -1.195791 -0.363566
# 2 -0.281556 -1.418608 -1.508746 -1.485550
# 3 -1.645558  0.587598  0.971253 -1.205811
# 4  0.010444 -0.059812 -0.996416 -1.391307
# 5 -0.460445  0.243995 -0.120536  0.616116
# 6  0.503948  0.660154  1.374157  1.830537
# 7  1.329392  1.125357 -2.740689  0.379360
# 8 -0.897418 -0.031701  0.960074  1.467141
# 9  0.472318 -1.046865  1.469804 -0.394370

# %%
#  break it into pieces
pieces = [df[:3], df[3:7], df[7:]] # this code is used to break the dataframe df into 3 pieces, first 3 rows, next 4 rows and remaining rows
pieces
# Out:
# [          0         1         2         3
#  0  0.369137  0.872269 -0.847942 -0.924365
#  1 -0.547641  1.301120 -1.195791 -0.363566
#  2 -0.281556 -1.418608 -1.508746 -1.485550,
#            0         1         2         3
#  3 -1.645558  0.587598  0.971253 -1.205811
#  4  0.010444 -0.059812 -0.996416 -1.391307
#  5 -0.460445  0.243995 -0.120536  0.616116
#  6  0.503948  0.660154  1.374157  1.830537,
#            0         1         2         3
#  7  1.329392  1.125357 -2.740689  0.379360
#  8 -0.897418 -0.031701  0.960074  1.467141
#  9  0.472318 -1.046865  1.469804 -0.394370]

# %%
pd.concat(pieces) # this code is used to concatenate the pieces of dataframe df
# Out:
#           0         1         2         3
# 0  0.369137  0.872269 -0.847942 -0.924365
# 1 -0.547641  1.301120 -1.195791 -0.363566
# 2 -0.281556 -1.418608 -1.508746 -1.485550
# 3 -1.645558  0.587598  0.971253 -1.205811
# 4  0.010444 -0.059812 -0.996416 -1.391307
# 5 -0.460445  0.243995 -0.120536  0.616116
# 6  0.503948  0.660154  1.374157  1.830537
# 7  1.329392  1.125357 -2.740689  0.379360
# 8 -0.897418 -0.031701  0.960074  1.467141
# 9  0.472318 -1.046865  1.469804 -0.394370

# %%
left = pd.DataFrame({"key" : ["foo" , "foo"], "lval" : [1,2]}) # this code is used to create a dataframe left with columns key and lval, key has values foo and bar and lval has values 1 and 2
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4,5]}) # this code is used to create a dataframe right with columns key and rval, key has values foo and bar and rval has values 4 and 5

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key") # this code is used to merge the dataframes left and right on the column key
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key" : ["foo" , "bar"], "lval" : [1,2]}) # this code is used to create a dataframe left with columns key and lval, key has values foo and bar and lval has values 1 and 2
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4,5]}) # this code is used to create a dataframe right with columns key and rval, key has values foo and bar and rval has values 4 and 5

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key") # this code is used to merge the dataframes left and right on the column key
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A" : ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B" : ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C" : np.random.randn(8),
        "D" : np.random.randn(8),
    }
)
# this code is used to create a dataframe df with columns A,B,C,D, A has values foo,bar,foo,bar,foo,bar,foo,foo, B has values one,one,two,three,two,two,one,three, C and D have random values
df
# Out:
#      A      B         C         D
# 0  foo    one -0.998530 -0.889751
# 1  bar    one -0.740045 -1.807384
# 2  foo    two -1.204014  2.137966
# 3  bar  three  1.089242 -0.092131
# 4  foo    two  0.792286  1.291784
# 5  bar    two  0.205512  0.027793
# 6  foo    one -2.212625  0.587102
# 7  foo  three  2.002929 -0.119955

# %%
df.groupby("A")[["C","D"]].sum()
# this code is used to group the dataframe df by column A and sum the values of columns C and D, the result will be a dataframe with columns A,C,D and values as sum of C and D grouped by A.
# Out:
#             C         D
# A
# bar  0.554709 -1.871722
# foo -1.619954  3.007145

# %%
df.groupby(["A","B"]).sum() # this code is used to group the dataframe df by columns A and B and sum the values of columns C and D, the result will be a dataframe with columns A,B,C,D and values as sum of C and D grouped by A and B.
# Out:
#                   C         D
# A   B
# bar one   -0.740045 -1.807384
#     three  1.089242 -0.092131
#     two    0.205512  0.027793
# foo one   -3.211154 -0.302649
#     three  2.002929 -0.119955
#     two   -0.411729  3.429749

# %%
arrays = [
    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
    ["one", "two", "one", "two", "one", "two", "one", "two"],
] # this code is used to create a list of lists arrays with values as bar,bar,baz,baz,foo,foo,qux,qux and one,two,one,two,one,two,one,two
arrays
# Out:
# [['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
#  ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"]) # this code is used to create a multi index from the arrays.
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"]) # this code is used to create a dataframe df with index as index and columns as A and B and random values
df
# Out:
#                      A         B
# first second
# bar   one    -0.014112  0.778055
#       two    -0.979416 -1.462409
# baz   one     1.856846  0.179817
#       two     0.887878  0.616015
# foo   one     0.605438  0.783955
#       two    -0.049380 -0.941482
# qux   one     1.679345 -0.048139
#       two     1.179479 -1.504624

# %%
df2 = df[:4] # this code is used to create a dataframe df2 with first 4 rows of df
df2
# Out:
#                      A         B
# first second
# bar   one    -0.014112  0.778055
#       two    -0.979416 -1.462409
# baz   one     1.856846  0.179817
#       two     0.887878  0.616015

# %%
stacked = df2.stack(future_stack=True) # this code is used to stack the dataframe df2, future_stack=True means that the stacked dataframe will have a multi index.
stacked
# Out:
# first  second
# bar    one     A   -0.014112
#                B    0.778055
#        two     A   -0.979416
#                B   -1.462409
# baz    one     A    1.856846
#                B    0.179817
#        two     A    0.887878
#                B    0.616015
# dtype: float64

# %%
stacked.unstack() # this code is used to unstack the dataframe stacked
# Out:
#                      A         B
# first second
# bar   one    -0.014112  0.778055
#       two    -0.979416 -1.462409
# baz   one     1.856846  0.179817
#       two     0.887878  0.616015

# %%
stacked.unstack(1) # this code is used to unstack the dataframe stacked by level 1
# Out:
# second        one       two
# first
# bar   A -0.014112 -0.979416
#       B  0.778055 -1.462409
# baz   A  1.856846  0.887878
#       B  0.179817  0.616015

# %%
stacked.unstack(0) # this code is used to unstack the dataframe stacked by level 0
# Out:
# first          bar       baz
# second
# one    A -0.014112  1.856846
#        B  0.778055  0.179817
# two    A -0.979416  0.887878
#        B -1.462409  0.616015

# %%
import datetime

df = pd.DataFrame(
    { 
        "A" : ["one", "one", "two", "three"] * 6,
        "B" : ["A", "B", "C"] * 8,
        "C" : ["foo", "foo", "foo", "bar", "bar", "bar"] * 4,
        "D" : np.random.randn(24),
        "E" : np.random.randn(24),
        "F" : [datetime.datetime(2023, i, 1) for i in range(1,13)] 
        + [datetime.datetime(2023, i, 15) for i in range(1,13)],
    }
) # this code is used to create a dataframe df with columns A,B,C,D,E,F, A has values one,one,two,three repeated 6 times, B has values A,B,C repeated 8 times, C has values foo,foo,foo,bar,bar,bar repeated 4 times, D and E have random values and F has dates from 20230101 to 20231215
df
# Out:
#         A  B    C         D         E          F
# 0     one  A  foo -1.234553 -1.830241 2023-01-01
# 1     one  B  foo  0.493502  0.453680 2023-02-01
# 2     two  C  foo  0.419898  1.005198 2023-03-01
# 3   three  A  bar -0.784425  0.212557 2023-04-01
# 4     one  B  bar  0.529957  0.673808 2023-05-01
# 5     one  C  bar  0.080799  0.789302 2023-06-01
# 6     two  A  foo -0.160511 -0.521446 2023-07-01
# 7   three  B  foo -0.083321 -0.018384 2023-08-01
# 8     one  C  foo -2.615740 -1.273951 2023-09-01
# 9     one  A  bar -0.415314 -0.968319 2023-10-01
# 10    two  B  bar -0.886412 -2.530008 2023-11-01
# 11  three  C  bar  0.244390 -0.727783 2023-12-01
# 12    one  A  foo  0.650148  0.459619 2023-01-15
# 13    one  B  foo -0.373676  0.235855 2023-02-15
# 14    two  C  foo -0.183891 -0.463532 2023-03-15
# 15  three  A  bar -0.059869 -1.082978 2023-04-15
# 16    one  B  bar -0.444106  0.307589 2023-05-15
# 17    one  C  bar  0.784143  0.699848 2023-06-15
# ...

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"]) 
# this code is used to create a pivot table with values as D, index as A and B and columns as C. 
# the result will be a dataframe with index as A and B, columns as foo and bar and values as D grouped by A,B and C.
# Out:
# C             bar       foo
# A     B
# one   A  0.832675 -0.292202
#       B  0.042925  0.059913
#       C  0.432471 -1.360721
# three A -0.422147       NaN
#       B       NaN  0.365834
#       C  1.084184       NaN
# two   A       NaN  0.180041
#       B  0.568698       NaN
#       C       NaN  0.118003

# %%
rng = pd.date_range("1/1/2023",periods=100, freq="S") # this code is used to create a date range from 20230101 to 20230411 with frequency as seconds
ts = pd.Series(np.random.randint(0,500,len(rng)),index=rng) # this code is used to create a series ts with random values and index as rng
ts.resample("5Min").sum() # this code is used to resample the series ts with frequency as 5 minutes and sum the values
# Out:
# 2023-01-01    24621
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range("1/11/2023 00:00", periods=5, freq="D") # this code is used to create a date range from 20230111 to 20230115 with frequency as days
ts = pd.Series(np.random.randn(len(rng)), rng) # this code is used to create a series ts with random values and index as rng
ts
# Out:
# 2023-01-11    1.657261
# 2023-01-12    0.126175
# 2023-01-13    0.096249
# 2023-01-14    0.167416
# 2023-01-15   -0.025289
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC") # this code is used 
ts_utc
# Out:
# 2023-01-11 00:00:00+00:00    1.657261
# 2023-01-12 00:00:00+00:00    0.126175
# 2023-01-13 00:00:00+00:00    0.096249
# 2023-01-14 00:00:00+00:00    0.167416
# 2023-01-15 00:00:00+00:00   -0.025289
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern") # this code is used
# Out:
# 2023-01-10 19:00:00-05:00    1.657261
# 2023-01-11 19:00:00-05:00    0.126175
# 2023-01-12 19:00:00-05:00    0.096249
# 2023-01-13 19:00:00-05:00    0.167416
# 2023-01-14 19:00:00-05:00   -0.025289
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2023-01-11', '2023-01-12', '2023-01-13', '2023-01-14',
#                '2023-01-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5) # this code is used to
# Out:
# DatetimeIndex(['2023-01-18', '2023-01-19', '2023-01-20', '2023-01-20',
#                '2023-01-20'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {
        "id":[1,2,3,4,5,6] , "raw_grade":["a", "b", "b", "a", "a", "e"]
    }
)
# this code is used to

# %%
df["grade"] = df["raw_grade"].astype("category") # this code is used to 
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)
#  this code is used to

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
) 
# this code is used to 

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade") # this code is used to
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size() # this code is used to
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all") # this code is used to

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000)) # this code is used to  
ts = ts.cumsum() # this code is used to 
ts.plot();

# %%
df = pd.DataFrame(

np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

df = df.cumsum()

plt.figure();
df.plot();

plt.legend(loc='best'); # this code is used to for

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,5, (10,5))) # this code is used to 
df.to_csv("foo.csv") # this code is used to

# %%
pd.read_csv("foo.csv") # this code is used to
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  0  3  3  0
# 1           1  0  3  0  4  0
# 2           2  3  1  1  2  4
# 3           3  3  4  3  2  4
# 4           4  2  1  3  4  4
# 5           5  4  1  3  0  3
# 6           6  1  1  4  2  1
# 7           7  0  3  3  2  1
# 8           8  4  4  0  3  1
# 9           9  4  1  4  0  3

# %%
pip install pyarrow
# Out:
# ...
#   Using cached pyarrow-14.0.0-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000024031F5E0C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/5b/16/6478c428e199653b8a4715f7087cd7c3884b306bd51648aa73afac7aae5e/pyarrow-14.0.0-cp312-cp312-win_amd64.whl
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/5b/16/6478c428e199653b8a4715f7087cd7c3884b306bd51648aa73afac7aae5e/pyarrow-14.0.0-cp312-cp312-win_amd64.whl
# ...

# %%
pip install fastparquet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000273D581FE60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/fastparquet/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000273D5D891F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/fastparquet/
# ...

# %%
pip install pyarrow *
# Out:
# ...
#   Using cached pyarrow-14.0.0-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# ...
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB 330.3 kB/s eta 0:01:16
#    ---------------------------------------- 0.0/25.0 MB 330.3 kB/s eta 0:01:16
#    ---------------------------------------- 0.0/25.0 MB 330.3 kB/s eta 0:01:16
#    ---------------------------------------- 0.1/25.0 MB 403.5 kB/s eta 0:01:02
#    ---------------------------------------- 0.1/25.0 MB 450.6 kB/s eta 0:00:56
#    ---------------------------------------- 0.1/25.0 MB 393.8 kB/s eta 0:01:04
#    ---------------------------------------- 0.2/25.0 MB 437.1 kB/s eta 0:00:57
#    ---------------------------------------- 0.2/25.0 MB 446.4 kB/s eta 0:00:56
#    ---------------------------------------- 0.2/25.0 MB 446.4 kB/s eta 0:00:56
# ...

# %%
import pyarrow.parquet as pq

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
table = pa.Table.from_pandas(df)
pq.write_table(table, 'foo.parquet')
# Out:
#   Cell In[4], line 7
#     pip install pyarrow
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df.to_parquet("foo.parquet") # this code is used to create a parquet file from the dataframe df	    df.to_parquet("foo.parquet") # this code is used to create a parquet file from the dataframe df

# %%
pd.read_parquet("foo.parquet") # this code is used to read the parquet file and create a dataframe df from it
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  0  3  3  0
# 1           1  0  3  0  4  0
# 2           2  3  1  1  2  4
# 3           3  3  4  3  2  4
# 4           4  2  1  3  4  4
# 5           5  4  1  3  0  3
# 6           6  1  1  4  2  1
# 7           7  0  3  3  2  1
# 8           8  4  4  0  3  1
# 9           9  4  1  4  0  3

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1") # this code is used to create an excel file from the dataframe df

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"]) # this code is used to read the excel file and create a dataframe df from it
# Out:
#    Unnamed: 0.1  Unnamed: 0  0  1  2  3  4
# 0             0           0  3  0  3  3  0
# 1             1           1  0  3  0  4  0
# 2             2           2  3  1  1  2  4
# 3             3           3  3  4  3  2  4
# 4             4           4  2  1  3  4  4
# 5             5           5  4  1  3  0  3
# 6             6           6  1  1  4  2  1
# 7             7           7  0  3  3  2  1
# 8             8           8  4  4  0  3  1
# 9             9           9  4  1  4  0  3

# %%
if pd.Series([False, True, False]).any(): # this code is used to check if the series has any True values or not 
    print("I was true") # this code is used to print I was true if the series has any True values or not
# Out:
# I was true
